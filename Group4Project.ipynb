# %% [markdown]
# # Scraping form Website Directly

# %%
import urllib.request 
import urllib.parse
import urllib.error
import ssl
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as BS

# For ignoring SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = "https://www.zillow.com/homes/san-francisco,-ca_rb/"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/2_p/?searchQueryState={%22pagination%22:{%22currentPage%22:2},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/3_p/?searchQueryState={%22pagination%22:{%22currentPage%22:3},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/4_p/?searchQueryState={%22pagination%22:{%22currentPage%22:4},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/5_p/?searchQueryState={%22pagination%22:{%22currentPage%22:5},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/6_p/?searchQueryState={%22pagination%22:{%22currentPage%22:6},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/7_p/?searchQueryState={%22pagination%22:{%22currentPage%22:7},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/8_p/?searchQueryState={%22pagination%22:{%22currentPage%22:8},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/9_p/?searchQueryState={%22pagination%22:{%22currentPage%22:9},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/10_p/?searchQueryState={%22pagination%22:{%22currentPage%22:10},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/11_p/?searchQueryState={%22pagination%22:{%22currentPage%22:11},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/12_p/?searchQueryState={%22pagination%22:{%22currentPage%22:12},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/13_p/?searchQueryState={%22pagination%22:{%22currentPage%22:13},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/14_p/?searchQueryState={%22pagination%22:{%22currentPage%22:14},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/15_p/?searchQueryState={%22pagination%22:{%22currentPage%22:15},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/16_p/?searchQueryState={%22pagination%22:{%22currentPage%22:16},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/17_p/?searchQueryState={%22pagination%22:{%22currentPage%22:17},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/18_p/?searchQueryState={%22pagination%22:{%22currentPage%22:18},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/19_p/?searchQueryState={%22pagination%22:{%22currentPage%22:19},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

url = "https://www.zillow.com/san-francisco-ca/20_p/?searchQueryState={%22pagination%22:{%22currentPage%22:20},%22usersSearchTerm%22:%22san%20francisco,%20ca%22,%22mapBounds%22:{%22west%22:-122.58868254614258,%22east%22:-122.27797545385742,%22south%22:37.69444721635087,%22north%22:37.85604738350627},%22mapZoom%22:13,%22savedSearchEnrollmentId%22:%22X1-SSsqf55yv112g60000000000_98wr7%22,%22regionSelection%22:[{%22regionId%22:20330,%22regionType%22:6}],%22isMapVisible%22:true,%22filterState%22:{%22sortSelection%22:{%22value%22:%22globalrelevanceex%22}},%22isListVisible%22:true}"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BS(webpage,'html.parser')
content_list=content_list + soup.findAll('a',attrs={'class':"list-card-link"})

#len(content_list)
#print(content_list)
#len(content_list)


#soup = BS(webpage,'html.parser')
#print (soup.title)
#html=soup.prettify()
soup.title
# Out:
# <title>San Francisco Real Estate - San Francisco CA Homes For Sale | Zillow</title>

# %% [markdown]
# # Using APIs
#
# https://blog.dominodatalab.com/exploring-us-real-estate-values-with-python/
#
# https://www.zillow.com/research/data/
#
# https://github.com/noahgift/real_estate_ml
#
# https://www.zillow.com/howto/api/APIOverview.htm
